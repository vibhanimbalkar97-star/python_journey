# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('./insurance.csv')
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %% [markdown]
# # EDA

# %% [markdown]
# # Step-1: Understand data
# head(), shape, info(), describe()

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df.shape
# Out:
# (1338, 7)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   str
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   str
#  5   region    1338 non-null   str
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), str(3)
# memory usage: 73.3 KB

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %% [markdown]
# # Step 2 — Missing values check

# %%
# df.isna().sum()
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %% [markdown]
# # Step 3 — Duplicates check

# %%
df.duplicated().sum()
# Out:
# np.int64(1)

# %% [markdown]
# # Step 4 — check distribution for numeric columns = normal, skewed
#  = → Histogram / KDE

# %%
df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='str')

# %%
# extract numeric columns
numeric_cols = ['age', 'bmi', 'children', 'charges']

for col in numeric_cols:
    plt.figure(figsize=(8, 6))
    sns.histplot(df[col], kde=True, bins=20)

# %% [markdown]
# # Step 5 - Analyze or check distribution for categorical columns = countplot
# yaha pe sirf input ko analyze kar rahe the

# %%
categorical_cols= ['sex', 'children', 'smoker']
for cols in categorical_cols:
    plt.figure(figsize=(8, 6))
    sns.countplot(x = df[cols])

# %% [markdown]
# # Step 6 - Detect outliers = use boxplot = for numeric values
# Input(Features, x) and output(target,y) ko connect karke analyze karege

# %%
for col in numeric_cols:
    plt.figure(figsize=(8, 6))
    sns.boxplot(x = df[col])

# %% [markdown]
# # Step 7 - Check relationships = correlation => Correlation matrix / heatmap

# %%
plt.figure(figsize=(8,6))
sns.heatmap(df.corr(numeric_only=True), annot=True)
# Out:
# <Axes: >

# %% [markdown]
# # Data cleaning and Preprocessing

# %%
df_cleaned = df.copy()
df_cleaned.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df_cleaned.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
df_cleaned.shape
# Out:
# (1338, 7)

# %%
df_cleaned.drop_duplicates(inplace=True)

# %%
df_cleaned.shape
# Out:
# (1337, 7)

# %%
df_cleaned.dtypes
# Out:
# age           int64
# sex             str
# bmi         float64
# children      int64
# smoker          str
# region          str
# charges     float64
# dtype: object

# %% [markdown]
# convert string dtype to numeric bcz to create ML model need all numeric data.
# how convert = by encoding 0 and 1.
# 2 values = label encoding
# more than 2 = one hot encoding means create new columns.

# %%
# check all str data
df_cleaned['sex'].value_counts()
# Out:
# sex
# male      675
# female    662
# Name: count, dtype: int64

# %%
# 2 values label encoding
df_cleaned['sex'] = df_cleaned['sex'].map({
    "male":0,
    "female":1
})

# %%
df_cleaned.head(3)
# Out:
#    age  sex    bmi  children smoker     region     charges
# 0   19    1  27.90         0    yes  southwest  16884.9240
# 1   18    0  33.77         1     no  southeast   1725.5523
# 2   28    0  33.00         3     no  southeast   4449.4620

# %%
df_cleaned['smoker'].value_counts()
# Out:
# smoker
# no     1063
# yes     274
# Name: count, dtype: int64

# %%
df_cleaned['smoker'] = df_cleaned['smoker'].map({
    "no":0,
    "yes":1
})

# %%
df_cleaned.head(3)
# Out:
#    age  sex    bmi  children  smoker     region     charges
# 0   19    1  27.90         0       1  southwest  16884.9240
# 1   18    0  33.77         1       0  southeast   1725.5523
# 2   28    0  33.00         3       0  southeast   4449.4620

# %% [markdown]
# # Rename columns

# %%
df_cleaned.rename(columns={
    "sex":"is_female",
    "smoker":"is_smoker"
}, inplace=True)

# %%
df_cleaned.head(3)
# Out:
#    age  is_female    bmi  children  is_smoker     region     charges
# 0   19          1  27.90         0          1  southwest  16884.9240
# 1   18          0  33.77         1          0  southeast   1725.5523
# 2   28          0  33.00         3          0  southeast   4449.4620

# %% [markdown]
# # one hot encoding

# %%
df_cleaned['region'].value_counts()
# Out:
# region
# southeast    364
# southwest    325
# northwest    324
# northeast    324
# Name: count, dtype: int64

# %%
df_cleaned = pd.get_dummies(df_cleaned, columns=['region'], drop_first=True)

# %%
df_cleaned.head(3)
# Out:
#    age  is_female    bmi  children  is_smoker     charges  region_northwest  \
# 0   19          1  27.90         0          1  16884.9240             False
# 1   18          0  33.77         1          0   1725.5523             False
# 2   28          0  33.00         3          0   4449.4620             False
#
#    region_southeast  region_southwest
# 0             False              True
# 1              True             False
# 2              True             False

# %%
df_cleaned = df_cleaned.astype(int)

# %%
df_cleaned.head(3)
# Out:
#    age  is_female  bmi  children  is_smoker  charges  region_northwest  \
# 0   19          1   27         0          1    16884                 0
# 1   18          0   33         1          0     1725                 0
# 2   28          0   33         3          0     4449                 0
#
#    region_southeast  region_southwest
# 0                 0                 1
# 1                 1                 0
# 2                 1                 0

# %% [markdown]
# # Feature Engineering and Extraction

# %% [markdown]
# # Feature Engineering

# %%
df_cleaned['bmi_category'] = pd.cut(df_cleaned['bmi'],
                           bins=[0, 18.5, 24.9, 29.9, float("inf")],
                           labels=['Underweight', 'Normal', 'Overweight', 'Obese'])

# %%
df_cleaned.head(3)
# Out:
#    age  is_female  bmi  children  is_smoker  charges  region_northwest  \
# 0   19          1   27         0          1    16884                 0
# 1   18          0   33         1          0     1725                 0
# 2   28          0   33         3          0     4449                 0
#
#    region_southeast  region_southwest bmi_category
# 0                 0                 1   Overweight
# 1                 1                 0        Obese
# 2                 1                 0        Obese

# %%
df_cleaned = pd.get_dummies(df_cleaned, columns=['bmi_category'], drop_first=True)

# %%
df_cleaned.head(3)
# Out:
#    age  is_female  bmi  children  is_smoker  charges  region_northwest  \
# 0   19          1   27         0          1    16884                 0
# 1   18          0   33         1          0     1725                 0
# 2   28          0   33         3          0     4449                 0
#
#    region_southeast  region_southwest  bmi_category_Normal  \
# 0                 0                 1                False
# 1                 1                 0                False
# 2                 1                 0                False
#
#    bmi_category_Overweight  bmi_category_Obese
# 0                     True               False
# 1                    False                True
# 2                    False                True

# %%
df_cleaned = df_cleaned.astype(int)

# %%
df_cleaned.head(3)
# Out:
#    age  is_female  bmi  children  is_smoker  charges  region_northwest  \
# 0   19          1   27         0          1    16884                 0
# 1   18          0   33         1          0     1725                 0
# 2   28          0   33         3          0     4449                 0
#
#    region_southeast  region_southwest  bmi_category_Normal  \
# 0                 0                 1                    0
# 1                 1                 0                    0
# 2                 1                 0                    0
#
#    bmi_category_Overweight  bmi_category_Obese
# 0                        1                   0
# 1                        0                   1
# 2                        0                   1

# %% [markdown]
# # Feature Scaling = standard = -3 to 3

# %%
from sklearn.preprocessing import StandardScaler 

cols=['age', 'bmi', 'children']

scaler = StandardScaler()

df_cleaned[cols] = scaler.fit_transform(df_cleaned[cols])

# %%
df_cleaned.head()
# Out:
#         age  is_female       bmi  children  is_smoker  charges  \
# 0 -1.440418          1 -0.517949 -0.909234          1    16884
# 1 -1.511647          0  0.462463 -0.079442          0     1725
# 2 -0.799350          0  0.462463  1.580143          0     4449
# 3 -0.443201          0 -1.334960 -0.909234          0    21984
# 4 -0.514431          0 -0.354547 -0.909234          0     3866
#
#    region_northwest  region_southeast  region_southwest  bmi_category_Normal  \
# 0                 0                 0                 1                    0
# 1                 0                 1                 0                    0
# 2                 0                 1                 0                    0
# 3                 1                 0                 0                    1
# 4                 1                 0                 0                    0
#
#    bmi_category_Overweight  bmi_category_Obese
# 0                        1                   0
# ...

# %% [markdown]
# # Pearsons correlation

# %%
from scipy.stats import pearsonr


# ----------------------------------
# Pearson Correlation Calculation
# ----------------------------------

# List of features to check against target
selected_features = ['age', 'is_female', 'bmi', 'children', 'is_smoker',
       'region_northwest', 'region_southeast', 'region_southwest', 'bmi_category_Normal', 'bmi_category_Overweight', 'bmi_category_Obese']

correlation = {
    feature: pearsonr(df_cleaned[feature], df_cleaned['charges'])[0]
    for feature in selected_features
}

# create dataframe
correlation_df = pd.DataFrame(list(correlation.items()), columns=['Feature', 'Pearsonr Correlation'])
correlation_df.sort_values(by='Pearsonr Correlation', ascending=False)

# sort values
# Out:
#                     Feature  Pearsonr Correlation
# 4                 is_smoker              0.787234
# 0                       age              0.298309
# 10       bmi_category_Obese              0.200348
# 2                       bmi              0.196236
# 6          region_southeast              0.073577
# 3                  children              0.067390
# 5          region_northwest             -0.038695
# 7          region_southwest             -0.043637
# 1                 is_female             -0.058046
# 8       bmi_category_Normal             -0.104042
# 9   bmi_category_Overweight             -0.120601

# %% [markdown]
# # chi-square test = category vs category
# charges is number to make category convert them in bins.
# qcut() creates bins based on percentiles, so the number of observations in each bin is approximately equal.

# %%
cat_features = [
     'is_female', 'is_smoker',
    'region_northwest', 'region_southeast', 'region_southwest',
    'bmi_category_Normal', 'bmi_category_Overweight', 'bmi_category_Obese'
]

# %%
from scipy.stats import chi2_contingency
import pandas as pd

alpha = 0.05

df_cleaned['charges_bin'] = pd.qcut(
    df_cleaned['charges'],
    q=4,
    labels=False
)

chi2_results={}

for col in cat_features:
    contingency = pd.crosstab(df_cleaned[col], df_cleaned['charges_bin'])
    chi2_stat, p_value, _, _ = chi2_contingency(contingency)
    decision='Reject Null (Keep Feature)' if p_value < alpha else 'Accept Null (Drop Feature)'
    chi2_results[col]={
        'chi2_statistics':chi2_stat,
        'p_value':p_value,
        'Decision':decision
    }
chi2_df = pd.DataFrame(chi2_results).T
chi2_df=chi2_df.sort_values(by='p_value')
chi2_df
# Out:
#                         chi2_statistics   p_value                    Decision
# is_smoker                    848.219178       0.0  Reject Null (Keep Feature)
# region_southeast              15.998167  0.001135  Reject Null (Keep Feature)
# is_female                     10.258784   0.01649  Reject Null (Keep Feature)
# bmi_category_Obese             8.515711  0.036473  Reject Null (Keep Feature)
# region_southwest               5.091893  0.165191  Accept Null (Drop Feature)
# bmi_category_Overweight         4.25149  0.235557  Accept Null (Drop Feature)
# bmi_category_Normal            3.708088   0.29476  Accept Null (Drop Feature)
# region_northwest                1.13424  0.768815  Accept Null (Drop Feature)

# %%
df_final =  df_cleaned[['age', 'is_female', 'bmi', 'children', 'is_smoker', 'charges','region_southeast','bmi_category_Obese']]
df_final
# Out:
#            age  is_female       bmi  children  is_smoker  charges  \
# 0    -1.440418          1 -0.517949 -0.909234          1    16884
# 1    -1.511647          0  0.462463 -0.079442          0     1725
# 2    -0.799350          0  0.462463  1.580143          0     4449
# 3    -0.443201          0 -1.334960 -0.909234          0    21984
# 4    -0.514431          0 -0.354547 -0.909234          0     3866
# ...        ...        ...       ...       ...        ...      ...
# 1333  0.767704          0 -0.027743  1.580143          0    10600
# 1334 -1.511647          1  0.135659 -0.909234          0     2205
# 1335 -1.511647          1  0.952670 -0.909234          0     1629
# 1336 -1.297958          1 -0.844753 -0.909234          0     2007
# 1337  1.551231          1 -0.191145 -0.909234          1    29141
#
#       region_southeast  bmi_category_Obese
# 0                    0                   0
# 1                    1                   1
# ...

# %%
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]
