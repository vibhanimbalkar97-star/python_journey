# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Creating a DataFrame
# pd.DataFrame()

# %%
#dict
data = {
    'Name': ['John', 'Anna', 'Peter', 'Linda'],
    'Age': [28, 34, 29, 42],
    'City': ['New York', 'Paris', 'Berlin', 'London'],
    'Salary': [65000, 70000, 62000, 85000]
}

df = pd.DataFrame(data)
df
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
#list
data_list = [
    ['John', 28, 'New York', 65000],
    ['Anna', 34, 'Paris', 70000],
    ['Peter', 29, 'Berlin', 62000],
    ['Linda', 42, 'London', 85000]
]
df1 = pd.DataFrame(data_list)
df1
# Out:
#        0   1         2      3
# 0   John  28  New York  65000
# 1   Anna  34     Paris  70000
# 2  Peter  29    Berlin  62000
# 3  Linda  42    London  85000

# %% [markdown]
# # Given custom column names

# %%
columns = ["Name", "Age", "City", "Salary"]
custom_column=pd.DataFrame(data_list, columns=columns)
custom_column
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %% [markdown]
# # selection and indexing of columns
# x=0, y=1

# %%
df
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %% [markdown]
# # select using column names = df['column name], multiple column= df[["","",""]]

# %%
c_name = df['Name']
mulc_name = df[['Age','City','Salary']]

c_name, mulc_name
# Out:
# (0     John
#  1     Anna
#  2    Peter
#  3    Linda
#  Name: Name, dtype: str,
#     Age      City  Salary
#  0   28  New York   65000
#  1   34     Paris   70000
#  2   29    Berlin   62000
#  3   42    London   85000)

# %% [markdown]
# # creating new column = df['column name'] =[values]

# %%
df['Designation']=["Doctor","Eng.","Doctor","Eng."]
df
# Out:
#     Name  Age      City  Salary Designation
# 0   John   28  New York   65000      Doctor
# 1   Anna   34     Paris   70000        Eng.
# 2  Peter   29    Berlin   62000      Doctor
# 3  Linda   42    London   85000        Eng.

# %% [markdown]
# # removing column names = df.drop(column name, axis), axis not given by default 0 means x axis, which is row wise.
# # multiple column drop = df.drop([column names])

# %%
df.drop('Designation', axis=1)
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %% [markdown]
# #  we remove column but it is not removed from original DF, so need to use inplace.

# %%
df
# Out:
#     Name  Age      City  Salary Designation
# 0   John   28  New York   65000      Doctor
# 1   Anna   34     Paris   70000        Eng.
# 2  Peter   29    Berlin   62000      Doctor
# 3  Linda   42    London   85000        Eng.

# %%
df.drop('Designation', axis=1, inplace=True)
df
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
df
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %% [markdown]
# # remove row = df.drop(row, axis=0)

# %%
df.drop(0,axis=0)
# Out:
#     Name  Age    City  Salary
# 1   Anna   34   Paris   70000
# 2  Peter   29  Berlin   62000
# 3  Linda   42  London   85000

# %% [markdown]
# # selecting / Accessing rows = use df.loc[index], multiple=df.loc[[indexs]]
# # iloc= index location

# %%
df
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
row=df.iloc[0]
row
# Out:
# Name          John
# Age             28
# City      New York
# Salary       65000
# Name: 0, dtype: object

# %%
row1 = df.loc[[1,2]]
row1
# Out:
#     Name  Age    City  Salary
# 1   Anna   34   Paris   70000
# 2  Peter   29  Berlin   62000

# %% [markdown]
# # Selecting Subsets(some portion) of Rows and Columns = df.loc[[row]][[column names]]

# %%
df
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
df.loc[0]['Name']
# Out:
# 'John'

# %%
df.loc[[0]][['Name']]
# Out:
#    Name
# 0  John

# %%
df.loc[[1,3]][["Age","City"]]
# Out:
#    Age    City
# 1   34   Paris
# 3   42  London

# %% [markdown]
# # Conditional Selection = means selection based on >,<,>=,<=

# %%
df
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
#I only want to see those people whose age is above 30
df[df["Age"] > 30]
# Out:
#     Name  Age    City  Salary
# 1   Anna   34   Paris   70000
# 3  Linda   42  London   85000

# %%
#I only want poeple whose age is above 30 and their city must be paris
df[(df["Age"] > 30) & (df["City"] == "Paris")]
# Out:
#    Name  Age   City  Salary
# 1  Anna   34  Paris   70000
