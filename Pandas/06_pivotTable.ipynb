# %% [markdown]
# # Pivot Tables = pd.pivot_table()

# %%
import numpy as np
import pandas as pd

# %%
data = {
    'Date': pd.date_range('2023-01-01', periods=20),
    'Product': ['A', 'B', 'C', 'D'] * 5,
    'Region': ['East', 'West', 'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West',
               'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West', 'North', 'South'],
    'Sales': np.random.randint(100, 1000, 20),
    'Units': np.random.randint(10, 100, 20),
    'Rep': ['John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary',
            'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice']
}

df = pd.DataFrame(data)

df['Month'] = df['Date'].dt.month_name()
df['Quarter'] = 'Q' + df['Date'].dt.quarter.astype(str)
df
# Out:
#          Date Product Region  Sales  Units    Rep    Month Quarter
# 0  2023-01-01       A   East    198     84   John  January      Q1
# 1  2023-01-02       B   West    118     29   Mary  January      Q1
# 2  2023-01-03       C  North    522     12    Bob  January      Q1
# 3  2023-01-04       D  South    292     73  Alice  January      Q1
# 4  2023-01-05       A   East    380     36   John  January      Q1
# 5  2023-01-06       B   West    212     20   Mary  January      Q1
# 6  2023-01-07       C  North    175     94    Bob  January      Q1
# 7  2023-01-08       D  South    173     75  Alice  January      Q1
# 8  2023-01-09       A   East    451     50   John  January      Q1
# 9  2023-01-10       B   West    204     56   Mary  January      Q1
# 10 2023-01-11       C  North    184     54    Bob  January      Q1
# 11 2023-01-12       D  South    213     19  Alice  January      Q1
# 12 2023-01-13       A   East    373     73   John  January      Q1
# 13 2023-01-14       B   West    501     57   Mary  January      Q1
# 14 2023-01-15       C  North    447     37    Bob  January      Q1
# 15 2023-01-16       D  South    378     19  Alice  January      Q1
# 16 2023-01-17       A   East    369     75   John  January      Q1
# 17 2023-01-18       B   West    185     34   Mary  January      Q1
# 18 2023-01-19       C  North    628     41    Bob  January      Q1
# 19 2023-01-20       D  South    544     56  Alice  January      Q1

# %%
pd.pivot_table(df, values='Sales', index='Region', columns='Product')
# Out:
# Product      A      B      C      D
# Region
# East     354.2    NaN    NaN    NaN
# North      NaN    NaN  391.2    NaN
# South      NaN    NaN    NaN  320.0
# West       NaN  244.0    NaN    NaN

# %%
pd.pivot_table(df, values='Sales', index='Region', columns='Product', aggfunc='median')
# Out:
# Product      A      B      C      D
# Region
# East     373.0    NaN    NaN    NaN
# North      NaN    NaN  447.0    NaN
# South      NaN    NaN    NaN  292.0
# West       NaN  204.0    NaN    NaN

# %%
r=pd.pivot_table(df, values=['Sales', 'Units'], index='Region', columns='Product', aggfunc='median')
r
# Out:
#          Sales                      Units
# Product      A      B      C      D     A     B     C     D
# Region
# East     373.0    NaN    NaN    NaN  73.0   NaN   NaN   NaN
# North      NaN    NaN  447.0    NaN   NaN   NaN  41.0   NaN
# South      NaN    NaN    NaN  292.0   NaN   NaN   NaN  56.0
# West       NaN  204.0    NaN    NaN   NaN  34.0   NaN   NaN

# %% [markdown]
# # Cross Tabs = uses for counting purpose

# %%
pd.crosstab(df['Region'], df['Rep'])
# Out:
# Rep     Alice  Bob  John  Mary
# Region
# East        0    0     5     0
# North       0    5     0     0
# South       5    0     0     0
# West        0    0     0     5
