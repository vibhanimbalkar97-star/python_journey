# %%
import numpy as np
from scipy.stats import norm

# %%
sample = [172, 174, 168, 169, 171, 173, 175, 170, 169, 172]
sample_mean = np.mean(sample)
population_mean = 170 
population_std = 3
n = len(sample)

# %%
z_score = (sample_mean - population_mean) / (population_std / np.sqrt(n))
z_score
# Out:
# np.float64(1.3703203194063098)

# %%
p_value = 2 * ( 1 - norm.cdf (abs(z_score)) )
p_value
# Out:
# np.float64(0.17058693287143756)

# %%
alpha = 0.05
if p_value < alpha:
    print("Reject Null hypothesis")
else:
    print("Accept Null hypothesis")
# Out:
# Accept Null hypothesis

# %% [markdown]
# ### Z-Test — Sample Data for Notebook Practice
#
# Use this data in your notebook and calculate the **Z-score and p-value** yourself:
#
# # Your task
#
# 1. Calculate **sample mean**
# 2. Calculate **sample size**
# 3. Calculate **Z-score**
# 4. Calculate **p-value**
# 5. Take `α = 0.05`
# 6. Decide:
#
#    * Reject H₀
#    * OR Fail to reject H₀
#
# **Hypotheses:**
#
# ```text
# H₀: μ = 30
# H₁: μ ≠ 30
# ```

# %%
d1 = np.array([
    31, 29, 32, 30, 31,
    33, 28, 30, 32, 31,
    29, 31, 30, 32, 33,
    30, 31, 29, 32, 31
])
p_mean = 30
p_std = 5
s_mean = np.mean(d1)
n = len(d1)

# %%
z_score = (s_mean - p_mean) / (p_std / np.sqrt(n))
z_score
# Out:
# np.float64(0.6708203932499369)

# %%
p_value = 2 * (1 - norm.cdf(abs(z_score)))
p_value
# Out:
# np.float64(0.502334954360502)

# %%
alpha = 0.05
if p_value > alpha:
    print("Accept Null hypithesis")
else: 
    print("reject Null hypothesis")
# Out:
# Accept Null hypithesis

# %% [markdown]
# # Your task
#
# 1. Calculate **sample mean**
# 2. Calculate **sample size**
# 3. Calculate **Z-score**
# 4. Calculate **p-value**
# 5. Use `α = 0.05`
# 6. Decide:
#
#    * Reject H₀
#    * OR Fail to reject H₀

# %%
# Sample exam scores
d2 = np.array([
    82, 78, 85, 80, 81,
    79, 84, 83, 77, 86,
    80, 82, 81, 79, 85
])

p_mean = 75
p_std = 10
s_mean = np.mean(d2)
n = len(d2)

# %%
z_score = (s_mean - p_mean) / (p_std / np.sqrt(n))
z_score
# Out:
# np.float64(2.5045292305474636)

# %%
p_value = 2 * (1 - norm.cdf(abs(z_score)))
p_value
# Out:
# np.float64(0.012261447314216634)

# %%
alpha = 0.05
if p_value > alpha:
    print("Accept Null hypothesis")
else:
    print("Reject Null hypothesis")
# Out:
# Reject Null hypothesis
